# %% [markdown]
# # Lesson 3: Matplotlib Basics — Plotting with `pyplot`

# %% [markdown]
# ### ⚙️ Importing Matplotlib
#
# You usually import the plotting module like this:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Here:
# * `matplotlib` is the main library
# * `.pyplot` is a **module** inside it that gives you easy plotting functions
# * `plt` is a short nickname (so you can type less)

# %% [markdown]
# Add sample data

# %%
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 50]

# %% [markdown]
# `plt.plot(x, y)` creates the line connecting all the (x, y) points

# %%
plt.plot(x, y)
plt.show() # shows the graph

# %% [markdown]
# you can also assign it to a variable
#
# #### Saving it as graph lets you modify the line later if you want, for example:

# %%
graph = plt.plot(x, y)
graph[0].set_color('red')
graph[0].set_linestyle('--')
plt.show()

# No need to understand this code

# %% [markdown]
# ## **Part 3: Adding Labels, Title, Legend, and Grid**

# %%
plt.plot(x, y)
plt.xlabel("X Values")
plt.ylabel("Y = X Squared")
plt.show()

# %% [markdown]
# ### 🏷️ Step 2: Adding a Title

# %%
plt.title("Simple Line Plot Example") # Adds a title
plt.plot(x, y)
plt.xlabel("X Values")
plt.ylabel("Y = X Squared")
plt.show()

# %% [markdown]
# ### 🧭 Step 3: Adding a Legend (for multiple lines)

# %%
import numpy as np

x = np.arange(0,5+1)
y1 = np.array(x*x)
y2 = np.array(x*x*x)

plt.plot(x, y1, label="y = x²") # label = ... will show if you use plt.legend()
plt.plot(x, y2, label="y = x³")

plt.title("Comparison of x² and x³")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.legend()  # 👈 This shows the legend box
plt.show()

# %% [markdown]
# ### 🧾 Step 4: Adding a Grid

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5]
y = [0, 1, 4, 9, 16, 25]

plt.plot(x, y, label="y = x²")
plt.title("Simple Quadratic Growth")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.legend()
plt.grid(True) # ------> Add Grid
plt.show()

# %% [markdown]
# ## **Part 4: Customizing Line Styles, Colors, and Saving Your Plot**

# %% [markdown]
# ### 🎨 Step 1: Changing Line Color, Style, and Markers

# %%
x = [0, 1, 2, 3, 4, 5]
y = [0, 1, 4, 9, 16, 25]

plt.plot(x, y, color='green', linestyle='--', marker='o', label="y = x²")
plt.title("Customized Line Style Example")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Here’s what each option means:
#
# * `color='red'` → sets the line color
# * `linestyle='--'` → makes the line dashed (you can also use `'-'`, `':'`, or `'-.'`)
# * `marker='o'` → adds a circle marker for each data point

# %% [markdown]
# ### 🧩 Step 2: Common Style Shortcuts
#
# Matplotlib lets you use **format strings** — a shorthand for style:

# %%
plt.plot(x, y, 'ro--', label="red")
plt.show()

# %% [markdown]
# ### 💾 Step 3: Saving Your Plot
#
# When your chart looks great, you can save it instead of just displaying it.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0,10+1)
y = np.array(x*x)

plt.plot(x, y, 'ro-', label="y = x²") # ro -> no line, ro- -> with lines ro-- ->dash line
plt.title("Styled Line Plot Example")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.legend()
plt.grid(True)

plt.savefig("styled_plot.png", dpi=300)
plt.show()

# %% [markdown]
# * ro -> no line,
# * ro- -> with lines
# * ro-- ->dash line
